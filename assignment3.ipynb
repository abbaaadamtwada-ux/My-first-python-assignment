# %%
my_gold = ()
sisters = ("amina", "hauwa", "hafsa", "asiya")
brothers = ("muhd", "abdulfatah", "abdulmalik")
siblings = (sisters + brothers)
num_of_siblings = len(siblings)
parents = ("abdullahi", "safiyya")
family_members = (parents + siblings)
print("family_members;", family_members)
# Out:
# family_members; ('abdullahi', 'safiyya', 'amina', 'hauwa', 'hafsa', 'asiya', 'muhd', 'abdulfatah', 'abdulmalik')
